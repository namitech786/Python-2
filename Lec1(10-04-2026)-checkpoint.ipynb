# %%
import pandas as pd

df = pd.read_csv("diabetes_unclean.csv")
df
# Out:
#        ID  No_Pation Gender   AGE  Urea    Cr  HbA1c  Chol   TG  HDL  LDL  \
# 0     502      17975      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4
# 1     735      34221      M  26.0   4.5  62.0    4.9   3.7  1.4  1.1  2.1
# 2     420      47975      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4
# 3     680      87656      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4
# 4     504      34223      M  33.0   7.1  46.0    4.9   4.9  1.0  0.8  2.0
# ...   ...        ...    ...   ...   ...   ...    ...   ...  ...  ...  ...
# 1004  191     454316      M  55.0   NaN  62.0    6.8   5.3  2.0  1.0  3.5
# 1005  192     454316      M  55.0   4.8  88.0    NaN   5.7  4.0  0.9  3.3
# 1006  193     454316      M  62.0   6.3  82.0    6.7   5.3  2.0  1.0  3.5
# 1007  194     454316      F  57.0   4.1  70.0    9.3   5.3  3.3  1.0  1.4
# 1008  195       4543      f  55.0   4.1  34.0   13.9   5.4  1.6  1.6  3.1
#
#       VLDL   BMI CLASS
# 0      0.5  24.0     N
# 1      0.6  23.0     N
# 2      0.5  24.0     N
# 3      0.5  24.0     N
# 4      0.4  21.0     N
# ...    ...   ...   ...
# 1004   0.9  30.1    Y
# 1005   1.8  30.0    Y
# 1006   NaN  30.1    Y
# 1007   1.3  29.0    Y
# 1008   0.7  33.0    Y
#
# [1009 rows x 14 columns]

# %%
df.isnull()
# Out:
#          ID  No_Pation  Gender    AGE   Urea     Cr  HbA1c   Chol     TG  \
# 0     False      False   False  False  False  False  False  False  False
# 1     False      False   False  False  False  False  False  False  False
# 2     False      False   False  False  False  False  False  False  False
# 3     False      False   False  False  False  False  False  False  False
# 4     False      False   False  False  False  False  False  False  False
# ...     ...        ...     ...    ...    ...    ...    ...    ...    ...
# 1004  False      False   False  False   True  False  False  False  False
# 1005  False      False   False  False  False  False   True  False  False
# 1006  False      False   False  False  False  False  False  False  False
# 1007  False      False   False  False  False  False  False  False  False
# 1008  False      False   False  False  False  False  False  False  False
#
#         HDL    LDL   VLDL    BMI  CLASS
# 0     False  False  False  False  False
# 1     False  False  False  False  False
# 2     False  False  False  False  False
# 3     False  False  False  False  False
# 4     False  False  False  False  False
# ...     ...    ...    ...    ...    ...
# 1004  False  False  False  False  False
# 1005  False  False  False  False  False
# 1006  False  False   True  False  False
# 1007  False  False  False  False  False
# 1008  False  False  False  False  False
#
# [1009 rows x 14 columns]

# %%
df.isnull().sum()
# Out:
# ID           0
# No_Pation    0
# Gender       0
# AGE          1
# Urea         1
# Cr           2
# HbA1c        3
# Chol         2
# TG           2
# HDL          1
# LDL          2
# VLDL         1
# BMI          0
# CLASS        0
# dtype: int64

# %%
df = df.fillna(df.mean(numeric_only = True))

# %%
df.isnull().sum()
# Out:
# ID           0
# No_Pation    0
# Gender       0
# AGE          0
# Urea         0
# Cr           0
# HbA1c        0
# Chol         0
# TG           0
# HDL          0
# LDL          0
# VLDL         0
# BMI          0
# CLASS        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Gender'].unique()
# Out:
# array(['F', 'M', 'f'], dtype=object)

# %%
df['Gender'] = df['Gender'].replace('f','F')

# %%
df['Gender'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df['Gender'].value_counts()
# Out:
# Gender
# M    570
# F    439
# Name: count, dtype: int64

# %%
y = df[['CLASS']]
y
# Out:
#      CLASS
# 0        N
# 1        N
# 2        N
# 3        N
# 4        N
# ...    ...
# 1004    Y
# 1005    Y
# 1006    Y
# 1007    Y
# 1008    Y
#
# [1009 rows x 1 columns]

# %%
x = df.drop(['ID','No_Pation','CLASS'],axis = 1)

# %%
x
# Out:
#      Gender   AGE      Urea    Cr      HbA1c  Chol   TG  HDL  LDL      VLDL  \
# 0         F  50.0  4.700000  46.0   4.900000   4.2  0.9  2.4  1.4  0.500000
# 1         M  26.0  4.500000  62.0   4.900000   3.7  1.4  1.1  2.1  0.600000
# 2         F  50.0  4.700000  46.0   4.900000   4.2  0.9  2.4  1.4  0.500000
# 3         F  50.0  4.700000  46.0   4.900000   4.2  0.9  2.4  1.4  0.500000
# 4         M  33.0  7.100000  46.0   4.900000   4.9  1.0  0.8  2.0  0.400000
# ...     ...   ...       ...   ...        ...   ...  ...  ...  ...       ...
# 1004      M  55.0  5.131094  62.0   6.800000   5.3  2.0  1.0  3.5  0.900000
# 1005      M  55.0  4.800000  88.0   8.284155   5.7  4.0  0.9  3.3  1.800000
# 1006      M  62.0  6.300000  82.0   6.700000   5.3  2.0  1.0  3.5  1.850595
# 1007      F  57.0  4.100000  70.0   9.300000   5.3  3.3  1.0  1.4  1.300000
# 1008      F  55.0  4.100000  34.0  13.900000   5.4  1.6  1.6  3.1  0.700000
#
#        BMI
# 0     24.0
# 1     23.0
# 2     24.0
# 3     24.0
# 4     21.0
# ...    ...
# 1004  30.1
# 1005  30.0
# 1006  30.1
# 1007  29.0
# 1008  33.0
#
# [1009 rows x 11 columns]

# %%
x.shape
# Out:
# (1009, 11)

# %%
y.shape
# Out:
# (1009, 1)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size =0.2,random_state=10)

# %%
x_train
# Out:
#     Gender   AGE  Urea    Cr  HbA1c  Chol   TG  HDL  LDL  VLDL   BMI
# 180      F  49.0   3.8  56.0    5.1   6.0  3.5  1.1  3.5   1.6  25.0
# 579      F  56.0   5.6  46.0    9.1   5.6  5.8  1.6  1.7   1.0  35.0
# 384      M  77.0   6.2  99.0    7.2   3.2  1.1  0.8  2.0   0.5  29.0
# 476      M  54.0   3.7  87.0    8.0   4.5  2.2  0.5  3.1   1.0  26.0
# 430      F  60.0   4.5  39.0    8.7   5.2  2.1  0.8  3.6   0.9  27.0
# ..     ...   ...   ...   ...    ...   ...  ...  ...  ...   ...   ...
# 160      M  45.0   5.3  77.0   11.2   3.9  1.5  1.3  2.0  10.4  29.5
# 756      M  54.0   4.0  55.0   11.3   5.3  7.7  0.7  1.5   3.5  38.0
# 645      M  59.0   4.0  56.0   10.0   4.9  2.1  1.1  2.5   0.9  28.0
# 142      M  50.0   3.5  59.0    6.0   4.0  2.1  1.4  1.9   0.9  25.0
# 12       F  30.0   3.0  42.0    4.1   4.9  1.3  1.2  3.2   0.5  22.0
#
# [807 rows x 11 columns]

# %%
x_test
# Out:
#     Gender   AGE  Urea    Cr  HbA1c  Chol    TG  HDL  LDL  VLDL   BMI
# 891      F  56.0   4.0  38.0    7.7   6.1   2.3  1.6  3.6   1.0  26.0
# 753      F  68.0   4.2  41.0   11.9   4.0   1.1  2.3  1.1   0.5  30.0
# 452      M  63.0   4.3  42.0    9.0   4.2   3.4  0.9  2.0   1.0  26.0
# 667      F  61.0   2.5  45.0   11.6   9.7  13.8  1.0  3.1   6.3  33.0
# 353      M  55.0   4.6  77.0    6.5   6.0   1.5  1.3  4.1   0.6  30.0
# ..     ...   ...   ...   ...    ...   ...   ...  ...  ...   ...   ...
# 31       M  47.0   4.6  55.0    4.3   4.6   0.8  0.9  4.2   4.1  24.0
# 315      M  54.0   5.5  69.0   11.0   6.3   6.8  0.7  2.4   3.1  29.0
# 193      M  40.0   4.3  72.0    7.0   4.0   1.8  0.9  2.4  12.2  40.0
# 384      M  77.0   6.2  99.0    7.2   3.2   1.1  0.8  2.0   0.5  29.0
# 307      M  55.0   3.7  93.0    7.2   3.2   1.9  0.6  1.8   0.8  30.0
#
# [202 rows x 11 columns]

# %%
y_train
# Out:
#     CLASS
# 956     Y
# 134     P
# 999    Y
# 669     Y
# 368     Y
# ..    ...
# 840     Y
# 179     Y
# 964     Y
# 326     Y
# 935     Y
#
# [807 rows x 1 columns]

# %%
y_test
# Out:
#     CLASS
# 55      N
# 50      N
# 591     Y
# 783     Y
# 232     Y
# ..    ...
# 261     Y
# 203     Y
# 656     Y
# 235     Y
# 587     Y
#
# [202 rows x 1 columns]

# %%
x_train.shape
# Out:
# (807, 11)

# %%
y_train.shape
# Out:
# (807, 1)

# %%
x_test.shape
# Out:
# (202, 11)

# %%
y_test.shape
# Out:
# (202, 1)

# %%
df = pd.read_csv("car data.csv")
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# 2        Dealer       Manual      0
# 3        Dealer       Manual      0
# 4        Dealer       Manual      0
# ..          ...          ...    ...
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0
#
# [301 rows x 9 columns]

# %%
df.duplicated().sum()
# Out:
# np.int64(2)

# %%
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df = df.duplicated(['Owner','Transmission','Car_Name','Seller_Type'],axis = 1).sum()

# %%
df = pd.get_dummies(df,drop_first = True)
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[150], line 1
# ----> 1 df = pd.get_dummies(df,drop_first = True)
#       2 df
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\reshape\encoding.py:227, in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     225     result = concat(with_dummies, axis=1)
#     226 else:
# --> 227     result = _get_dummies_1d(
#     228         data,
#     229         prefix,
#     230         prefix_sep,
#     231         dummy_na,
#     232         sparse=sparse,
#     233         drop_first=drop_first,
#     234         dtype=dtype,
#     235     )
#     236 return result
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\reshape\encoding.py:296, in _get_dummies_1d(data, prefix, prefix_sep, dummy_na, sparse, drop_first, dtype)
#     294 # if dummy_na, we just fake a nan level. drop_first will drop it again
#     295 if drop_first and len(levels) == 1:
# --> 296     return get_empty_frame(data)
#     298 number_of_cols = len(levels)
#     300 if prefix is None:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\reshape\encoding.py:282, in _get_dummies_1d.<locals>.get_empty_frame(data)
#     280     index = data.index
#     281 else:
# --> 282     index = default_index(len(data))
#     283 return DataFrame(index=index)
#
# TypeError: object of type 'numpy.int64' has no len()
